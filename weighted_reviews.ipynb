# %%
import pandas as pd
import altair as alt
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('all_reviews.csv')
df.columns
df.head()
# Out:
#    teacher_id attendance clarityColor easyColor helpColor  helpCount  \
# 0     1000064        NaN         good      poor      good          1
# 1     1000064        NaN         good   average      good          1
# 2     1007241  Mandatory      average      good   average          3
# 3     1007241        NaN         poor      good      poor          0
# 4     1007241        NaN         good   average      good          0
#
#          id  notHelpCount onlineClass  quality  ...     rTimestamp  \
# 0  25262261             0         NaN  awesome  ...  1445096719000
# 1  13252233             0         NaN  awesome  ...  1181323024000
# 2  27179836             0         NaN     poor  ...  1479119749000
# 3  18307613             2         NaN    awful  ...  1300970532000
# 4  17041715             0         NaN  awesome  ...  1271948269000
#
#   rWouldTakeAgain   sId takenForCredit  teacher  teacherGrade  \
# 0             NaN  1452            Yes      NaN           NaN
# 1             NaN  1452            NaN      NaN           NaN
# 2              No  1452            Yes      NaN           NaN
# 3             NaN  1452            NaN      NaN           NaN
# 4             NaN  1452            NaN      NaN           NaN
#
#                         teacherRatingTags  unUsefulGrouping usefulGrouping  \
# 0  ['Inspirational', 'Amazing lectures ']            people         person
# 1                                      []            people         person
# 2       ['Tough grader', 'Lecture heavy']            people         people
# 3                                      []            people         people
# 4                                      []            people         people
#
#    overall_rating
# 0             5.0
# 1             5.0
# 2             2.7
# 3             2.7
# 4             2.7
#
# [5 rows x 33 columns]

# %%
for col in df:
    print(col,": ",df[col].unique())
# Out:
# teacher_id :  [1000064 1007241 1007871 ...   99449   99765   99965]
# attendance :  [nan 'Mandatory' 'Not Mandatory']
# clarityColor :  ['good' 'average' 'poor']
# easyColor :  ['poor' 'average' 'good']
# helpColor :  ['good' 'average' 'poor']
# helpCount :  [  1   3   0   2   5   6   7  11  24  22  10  12   8   9  16   4  23  28
#   26  14  19  15  13  39  17  36  27  38  18 160  20  21  31  34  33  76
#   58  25  55  30  40 354  43  32  44  29  64 230  48  49  37  57  61  41
#   42  46  50  67  45  35 105  65 179  88  60  72  54  75  69  70  92  66]
# id :  [25262261 13252233 27179836 ...   538291   446406   435980]
# notHelpCount :  [  0   2   1   3   4  11   8   5   6   9  13   7  17  18  20  14  16  12
#   10  34  15  19  25  22  21 105 173 117  26  45  74  24  78 103  30  33
#   29  39  23  38 112  41 141  35  44  36  28  31  37  27  72  32  47  42
#   46 197  55  49  43  58  70  52  60  63  75  51  59 114  48 249 118  71
#   85  96  91]
# onlineClass :  [nan 'online']
# quality :  ['awesome' 'poor' 'awful' 'good' 'average']
# rClarity :  [5 2 1 4 3]
# rClass :  ['MED1105' 'TMM3501' 'BCH4125' ... 'HIS2770' 'HISSOMETHING' 'LATINAMERHIS']
# rComments :  ['Best prof ever! '
#  'An excellent lecturer with a clear, concise style. She uses class time so well that it flies right by, and somehow has time to answer questions.  Extremely approachable and truly cares about her students, their learning, and their well-being.  I look forward to any course I have with her.  Ottawa U is very fortunate to have her on faculty!'
#  'Stupid questions on the midterm.' ...
#  'Definitely a language prob there, lack of structure & direction was frustrating'
#  'Clarity was somewhat of a problem, material was very interesting.  Good class.'
#  'should teach the class in french!!!']
# rDate :  ['10/17/2015' '06/08/2007' '11/14/2016' ... '06/08/2019' '06/19/2004'
#  '06/09/2008']
# rEasy :  [1. 2. 5. 4. 3.]
# rEasyString :  [1. 2. 5. 4. 3.]
# rErrorMsg :  [nan]
# rHelpful :  [5 2 1 4 3]
# rInterest :  ['Really into it' 'Sorta interested' nan 'Meh' "It's my life" 'Low']
# rOverall :  [5.  2.  1.  4.  3.  3.5 2.5 1.5 4.5]
# rOverallString :  [5.  2.  1.  4.  3.  3.5 2.5 1.5 4.5]
# rStatus :  [1 0 3]
# rTextBookUse :  ['No' nan 'Yes']
# rTimestamp :  [1445096719000 1181323024000 1479119749000 ... 1044312400000 1040181657000
#  1039981923000]
# rWouldTakeAgain :  [nan 'No' 'Yes']
# sId :  [1452    0 4056  743 1443 1420  481]
# takenForCredit :  ['Yes' nan 'No']
# teacher :  [nan]
# teacherGrade :  [nan 'WD' 'A-' 'A+' 'Not sure yet' 'INC' 'C+' 'B-' 'B' 'A' 'B+' 'C' 'D'
#  'C-' 'D+' 'F' 'D-' 'Audit/No Grade' 'P']
# teacherRatingTags :  ["['Inspirational', 'Amazing lectures ']" '[]'
#  "['Tough grader', 'Lecture heavy']" ...
#  "['Lecture heavy', 'Graded by few things', 'Caring']"
#  "['EXTRA CREDIT', 'Respected', 'Clear grading criteria']"
#  "['Graded by few things', 'Lecture heavy', 'Group projects']"]
# unUsefulGrouping :  ['people' 'person']
# usefulGrouping :  ['person' 'people']
# overall_rating :  [5.  2.7 3.7 3.8 3.9 2.  4.5 4.8 3.6 2.8 4.6 3.2 4.2 3.3 2.3 2.5 3.5 2.1
#  1.7 4.  4.3 3.1 2.6 4.7 3.  4.4 4.1 2.2 3.4 2.9 1.9 4.9 1.5 1.6 1.  2.4
#  1.3 1.8 1.4 1.2 1.1 nan]

# %%
#mapping the helpColor to numeric vals to assign weights to every review for use in prediction
dict_map = {'good':3,'average':2,'poor':1}
df['helpColor_weight'] = df['helpColor'].map(dict_map)
df
# Out:
#        teacher_id attendance clarityColor easyColor helpColor  helpCount  \
# 0         1000064        NaN         good      poor      good          1
# 1         1000064        NaN         good   average      good          1
# 2         1007241  Mandatory      average      good   average          3
# 3         1007241        NaN         poor      good      poor          0
# 4         1007241        NaN         good   average      good          0
# ...           ...        ...          ...       ...       ...        ...
# 63946       99965        NaN         good      good      good          0
# 63947       99965        NaN         poor   average   average          0
# 63948       99965        NaN         poor   average      poor          0
# 63949       99965        NaN      average   average   average          0
# 63950       99965        NaN      average   average   average          0
#
#              id  notHelpCount onlineClass  quality  ...   sId takenForCredit  \
# 0      25262261             0         NaN  awesome  ...  1452            Yes
# 1      13252233             0         NaN  awesome  ...  1452            NaN
# 2      27179836             0         NaN     poor  ...  1452            Yes
# 3      18307613             2         NaN    awful  ...  1452            NaN
# 4      17041715             0         NaN  awesome  ...  1452            NaN
# ...         ...           ...         ...      ...  ...   ...            ...
# 63946   1408578             0         NaN     good  ...  1452            NaN
# 63947    642117             0         NaN  average  ...  1452            NaN
# 63948    538291             0         NaN     poor  ...  1452            NaN
# 63949    446406             0         NaN     good  ...  1452            NaN
# 63950    435980             0         NaN     good  ...  1452            NaN
#
#       teacher teacherGrade                       teacherRatingTags  \
# 0         NaN          NaN  ['Inspirational', 'Amazing lectures ']
# 1         NaN          NaN                                      []
# 2         NaN          NaN       ['Tough grader', 'Lecture heavy']
# 3         NaN          NaN                                      []
# 4         NaN          NaN                                      []
# ...       ...          ...                                     ...
# 63946     NaN          NaN                                      []
# 63947     NaN          NaN                                      []
# 63948     NaN          NaN                                      []
# 63949     NaN          NaN                                      []
# 63950     NaN          NaN                                      []
#
#        unUsefulGrouping  usefulGrouping  overall_rating review_weight  \
# 0                people          person             5.0             3
# 1                people          person             5.0             3
# 2                people          people             2.7             2
# 3                people          people             2.7             1
# 4                people          people             2.7             3
# ...                 ...             ...             ...           ...
# 63946            people          people             3.0             3
# 63947            people          people             3.0             2
# 63948            people          people             3.0             1
# 63949            people          people             3.0             2
# 63950            people          people             3.0             2
#
#        helpColor_weight
# 0                     3
# 1                     3
# 2                     2
# 3                     1
# 4                     3
# ...                 ...
# 63946                 3
# 63947                 2
# 63948                 1
# 63949                 2
# 63950                 2
#
# [63951 rows x 35 columns]

# %%
#and then going further, we have the columns helpCount and notHelpCount, taking this to mean the number of people that
#found a particular review helpful and unhelpful respectively, we can end up with the overall review weights
# formula = helpColorWeight + helpCount - notHelpCount

# e.g cases: 
#helpColor - good, helpCount - 0, notHelpCount - 0, review weight = 3 + 0 - 0 = 3
# helpColor - poor, helpCount - 0, notHelpCount - 2 , review weight = 1 + 0 -2 = -1

df['review_weight'] = df['helpColor_weight'] + df['helpCount'] - df['notHelpCount']
df
# Out:
#        teacher_id attendance clarityColor easyColor helpColor  helpCount  \
# 0         1000064        NaN         good      poor      good          1
# 1         1000064        NaN         good   average      good          1
# 2         1007241  Mandatory      average      good   average          3
# 3         1007241        NaN         poor      good      poor          0
# 4         1007241        NaN         good   average      good          0
# ...           ...        ...          ...       ...       ...        ...
# 63946       99965        NaN         good      good      good          0
# 63947       99965        NaN         poor   average   average          0
# 63948       99965        NaN         poor   average      poor          0
# 63949       99965        NaN      average   average   average          0
# 63950       99965        NaN      average   average   average          0
#
#              id  notHelpCount onlineClass  quality  ...   sId takenForCredit  \
# 0      25262261             0         NaN  awesome  ...  1452            Yes
# 1      13252233             0         NaN  awesome  ...  1452            NaN
# 2      27179836             0         NaN     poor  ...  1452            Yes
# 3      18307613             2         NaN    awful  ...  1452            NaN
# 4      17041715             0         NaN  awesome  ...  1452            NaN
# ...         ...           ...         ...      ...  ...   ...            ...
# 63946   1408578             0         NaN     good  ...  1452            NaN
# 63947    642117             0         NaN  average  ...  1452            NaN
# 63948    538291             0         NaN     poor  ...  1452            NaN
# 63949    446406             0         NaN     good  ...  1452            NaN
# 63950    435980             0         NaN     good  ...  1452            NaN
#
#       teacher teacherGrade                       teacherRatingTags  \
# 0         NaN          NaN  ['Inspirational', 'Amazing lectures ']
# 1         NaN          NaN                                      []
# 2         NaN          NaN       ['Tough grader', 'Lecture heavy']
# 3         NaN          NaN                                      []
# 4         NaN          NaN                                      []
# ...       ...          ...                                     ...
# 63946     NaN          NaN                                      []
# 63947     NaN          NaN                                      []
# 63948     NaN          NaN                                      []
# 63949     NaN          NaN                                      []
# 63950     NaN          NaN                                      []
#
#        unUsefulGrouping  usefulGrouping  overall_rating review_weight  \
# 0                people          person             5.0             4
# 1                people          person             5.0             4
# 2                people          people             2.7             5
# 3                people          people             2.7            -1
# 4                people          people             2.7             3
# ...                 ...             ...             ...           ...
# 63946            people          people             3.0             3
# 63947            people          people             3.0             2
# 63948            people          people             3.0             1
# 63949            people          people             3.0             2
# 63950            people          people             3.0             2
#
#        helpColor_weight
# 0                     3
# 1                     3
# 2                     2
# 3                     1
# 4                     3
# ...                 ...
# 63946                 3
# 63947                 2
# 63948                 1
# 63949                 2
# 63950                 2
#
# [63951 rows x 35 columns]
